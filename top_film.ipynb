# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
top_film =pd.read_csv('imdb_top_1000.csv')
top_film = top_film.drop(['Poster_Link','Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes','Overview','Certificate'],axis =1)

# %%
top_film.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Meta_score', 'Director', 'Gross'],
#       dtype='object')

# %%
sns.jointplot(x='Meta_score',y='IMDB_Rating',data=top_film, hue ='Genre')

# %%
sns.heatmap(top_film.corr())
# Out:
# C:\Users\moula\AppData\Local\Temp\ipykernel_9220\580571197.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(top_film.corr())
# <AxesSubplot: >

# %%
top_film.groupby(['Released_Year']).mean()
# Out:
# C:\Users\moula\AppData\Local\Temp\ipykernel_9220\3554285999.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top_film.groupby(['Released_Year']).mean()
#                IMDB_Rating  Meta_score         Gross
# Released_Year
# 1920              8.100000         NaN  5.397400e+05
# 1921              8.300000         NaN  5.450000e+06
# 1922              7.900000         NaN  1.000020e+07
# 1924              8.200000         NaN  9.773750e+05
# 1925              8.100000   97.000000  2.750485e+06
# ...                    ...         ...           ...
# 2017              7.890909   79.473684  9.377243e+07
# 2018              7.994737   77.692308  1.381231e+08
# 2019              7.995652   76.904762  1.085554e+08
# 2020              8.133333   82.750000  4.512098e+06
# ...

# %%
top_film80 = top_film[(top_film['IMDB_Rating'] > 8.5)]
top_film80=top_film80[top_film80['Meta_score'] > 90]
top_film80[top_film80['Released_Year']>'1970']
# Out:
#                                          Series_Title Released_Year  Runtime  \
# 1                                       The Godfather          1972  175 min
# 5       The Lord of the Rings: The Return of the King          2003  201 min
# 6                                        Pulp Fiction          1994  154 min
# 7                                    Schindler's List          1993  195 min
# 10  The Lord of the Rings: The Fellowship of the Ring          2001  178 min
# 19                                       Gisaengchung          2019  132 min
# 23                      Sen to Chihiro no kamikakushi          2001  125 min
# 24                                Saving Private Ryan          1998  169 min
#
#         Genre  IMDB_Rating  Meta_score              Director      Gross
# 1       Crime          9.2       100.0  Francis Ford Coppola  134966411
# 5      Action          8.9        94.0         Peter Jackson  377845905
# ...

# %%
sns.boxplot(x='Genre',y='IMDB_Rating',data=top_film)
# Out:
# <AxesSubplot: xlabel='Genre', ylabel='IMDB_Rating'>

# %%
sns.boxplot(x='Genre',y='Meta_score',data=top_film)
# Out:
# <AxesSubplot: xlabel='Genre', ylabel='Meta_score'>

# %%
top_film8 = top_film[top_film['Released_Year']>'1980']
nbr_film_an=top_film8.groupby(['Released_Year']).count()
type(nbr_film_an)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.catplot(x='Released_Year',y='Series_Title',data=nbr_film_an)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\moula\Projets code\Projet data analyst\1000 best movies\top_film.ipynb Cellule 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/moula/Projets%20code/Projet%20data%20analyst/1000%20best%20movies/top_film.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> sns.catplot(x='Released_Year',y='Series_Title',data=nbr_film_an)
#
# NameError: name 'nbr_film_an' is not defined

# %%
sns.pairplot(data=top_film,hue ='Genre')
